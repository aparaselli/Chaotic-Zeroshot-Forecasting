# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('attractor_data.csv')

# %%
a = eval(df[df['attractor'] == 'Aizawa_x_0']['values'].values[0])

# %%
a[:10]
# Out:
# [-0.78450179,
#  -0.7830082214348854,
#  -0.7815131745822561,
#  -0.7800166566417908,
#  -0.7785186748121669,
#  -0.7770192362909397,
#  -0.7755183482745602,
#  -0.774016017958354,
#  -0.7725122525364068,
#  -0.7710070592016942]

# %%
df['attractor'].values
# Out:
# array(['Aizawa_x_0', 'Aizawa_x_1', 'Aizawa_x_2',
#        'AnishchenkoAstakhov_x_0', 'AnishchenkoAstakhov_x_1',
#        'AnishchenkoAstakhov_x_2', 'Arneodo_x_0', 'Arneodo_x_1',
#        'Arneodo_x_2', 'ArnoldBeltramiChildress_x_0',
#        'ArnoldBeltramiChildress_x_1', 'ArnoldBeltramiChildress_x_2',
#        'ArnoldWeb_x_0', 'ArnoldWeb_x_1', 'ArnoldWeb_x_2', 'ArnoldWeb_x_3',
#        'ArnoldWeb_x_4', 'AtmosphericRegime_x_0', 'AtmosphericRegime_x_1',
#        'AtmosphericRegime_x_2', 'BeerRNN_x_0', 'BeerRNN_x_1',
#        'BeerRNN_x_2', 'BelousovZhabotinsky_x_0',
#        'BelousovZhabotinsky_x_1', 'BelousovZhabotinsky_x_2',
#        'BickleyJet_x_0', 'BickleyJet_x_1', 'BickleyJet_x_2',
#        'Blasius_x_0', 'Blasius_x_1', 'Blasius_x_2', 'BlinkingRotlet_x_0',
#        'BlinkingRotlet_x_1', 'BlinkingRotlet_x_2', 'BlinkingVortex_x_0',
#        'BlinkingVortex_x_1', 'BlinkingVortex_x_2', 'Bouali_x_0',
#        'Bouali_x_1', 'Bouali_x_2', 'Bouali2_x_0', 'Bouali2_x_1',
# ...
