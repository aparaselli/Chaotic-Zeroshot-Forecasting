# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('../Data/BATS_zooplankton.csv')
df.columns = df.iloc[34]
df = df[35:].reset_index(drop=True)
df.head(5)
# Out:
# 34 Cruise      Date Tow Latitiude_Deg Latitude_Min Longitude_Deg  \
# 0   20066  19940406   1            31        33.89            63
# 1   20066  19940406   1            31        33.89            63
# 2   20066  19940406   1            31        33.89            63
# 3   20066  19940406   1            31        33.89            63
# 4   20066  19940406   1            31        33.89            63
#
# 34 Longitude_Min Time_in Time_out Duration_min  ... Wet_weight Dry_weight  \
# 0          52.45    1558     1626           28  ...       2460      210.4
# 1          52.45    1558     1626           28  ...       1220      120.2
# 2          52.45    1558     1626           28  ...       2200      110.4
# 3          52.45    1558     1626           28  ...        940       94.4
# 4          52.45    1558     1626           28  ...        460       36.2
#
# 34 Wet_weight/vol Dry_weight/vol Total_wet/vol Total_dry/vol Wet/vol_norm  \
# 0           18.15           1.55         53.73          4.22      3630.98
# 1               9           0.89         53.73          4.22      1800.73
# 2           16.24           0.81         53.73          4.22      3247.22
# 3            6.94            0.7         53.73          4.22      1387.45
# 4            3.39           0.27         53.73          4.22       678.96
#
# 34 Dry/vol_norm Total_wet/vol_norm Total_dry/vol_norm
# 0        310.55           10745.33             843.69
# 1        177.42           10745.33             843.69
# 2        162.95           10745.33             843.69
# 3        139.34           10745.33             843.69
# 4         53.43           10745.33             843.69
#
# [5 rows x 23 columns]

# %%
df.isna().sum() #NO NAN Values
# Out:
# 34
# Cruise                0
# Date                  0
# Tow                   0
# Latitiude_Deg         0
# Latitude_Min          0
# Longitude_Deg         0
# Longitude_Min         0
# Time_in               0
# Time_out              0
# Duration_min          0
# Max_depth             0
# Water_Vol             0
# Sieve_Size            0
# Wet_weight            0
# Dry_weight            0
# Wet_weight/vol        0
# Dry_weight/vol        0
# Total_wet/vol         0
# Total_dry/vol         0
# Wet/vol_norm          0
# Dry/vol_norm          0
# Total_wet/vol_norm    0
# Total_dry/vol_norm    0
# dtype: int64

# %%
#Convert to date time 
df['Date'] = pd.to_datetime(df['Date'].astype(str), format='%Y%m%d')
df
# Out:
# 34   Cruise       Date Tow Latitiude_Deg Latitude_Min Longitude_Deg  \
# 0     20066 1994-04-06   1            31        33.89            63
# 1     20066 1994-04-06   1            31        33.89            63
# 2     20066 1994-04-06   1            31        33.89            63
# 3     20066 1994-04-06   1            31        33.89            63
# 4     20066 1994-04-06   1            31        33.89            63
# ...     ...        ...  ..           ...          ...           ...
# 7294  10399 2022-12-13   4            31       38.242            64
# 7295  10399 2022-12-13   4            31       38.242            64
# 7296  10399 2022-12-13   4            31       38.242            64
# 7297  10399 2022-12-13   4            31       38.242            64
# 7298  10399 2022-12-13   4            31       38.242            64
#
# 34   Longitude_Min Time_in Time_out Duration_min  ... Wet_weight Dry_weight  \
# 0            52.45    1558     1626           28  ...       2460      210.4
# 1            52.45    1558     1626           28  ...       1220      120.2
# 2            52.45    1558     1626           28  ...       2200      110.4
# 3            52.45    1558     1626           28  ...        940       94.4
# 4            52.45    1558     1626           28  ...        460       36.2
# ...            ...     ...      ...          ...  ...        ...        ...
# 7294        12.072    2243     2319           36  ...     2599.6      385.2
# 7295        12.072    2243     2319           36  ...     4246.8      669.6
# 7296        12.072    2243     2319           36  ...     2469.6      446.8
# 7297        12.072    2243     2319           36  ...       1153      251.4
# 7298        12.072    2243     2319           36  ...      24056     3169.8
#
# 34   Wet_weight/vol Dry_weight/vol Total_wet/vol Total_dry/vol Wet/vol_norm  \
# 0             18.15           1.55         53.73          4.22      3630.98
# 1                 9           0.89         53.73          4.22      1800.73
# 2             16.24           0.81         53.73          4.22      3247.22
# 3              6.94            0.7         53.73          4.22      1387.45
# 4              3.39           0.27         53.73          4.22       678.96
# ...             ...            ...           ...           ...          ...
# 7294           1.73           0.26         23.04          3.28       346.91
# 7295           2.83           0.45         23.04          3.28       566.73
# 7296           1.65            0.3         23.04          3.28       329.56
# 7297           0.77           0.17         23.04          3.28       153.87
# 7298          16.05           2.12         23.04          3.28      3210.22
#
# 34   Dry/vol_norm Total_wet/vol_norm Total_dry/vol_norm
# 0          310.55           10745.33             843.69
# 1          177.42           10745.33             843.69
# 2          162.95           10745.33             843.69
# 3          139.34           10745.33             843.69
# 4           53.43           10745.33             843.69
# ...           ...                ...                ...
# 7294         51.4            4607.28             656.94
# 7295        89.36            4607.28             656.94
# 7296        59.62            4607.28             656.94
# 7297        33.55            4607.28             656.94
# 7298          423            4607.28             656.94
#
# [7299 rows x 23 columns]

# %%
dt_gb = df.groupby('Date').count().reset_index()
dt_gb
# Out:
# 34        Date  Cruise  Tow  Latitiude_Deg  Latitude_Min  Longitude_Deg  \
# 0   1994-04-06      18   18             18            18             18
# 1   1994-04-18      10   10             10            10             10
# 2   1994-04-19       8    8              8             8              8
# 3   1994-05-17      20   20             20            20             20
# 4   1994-06-13      10   10             10            10             10
# ..         ...     ...  ...            ...           ...            ...
# 586 2022-09-18      10   10             10            10             10
# 587 2022-10-12      20   20             20            20             20
# 588 2022-11-23      10   10             10            10             10
# 589 2022-11-24      10   10             10            10             10
# 590 2022-12-13      20   20             20            20             20
#
# 34   Longitude_Min  Time_in  Time_out  Duration_min  ...  Wet_weight  \
# 0               18       18        18            18  ...          18
# 1               10       10        10            10  ...          10
# 2                8        8         8             8  ...           8
# 3               20       20        20            20  ...          20
# 4               10       10        10            10  ...          10
# ..             ...      ...       ...           ...  ...         ...
# 586             10       10        10            10  ...          10
# 587             20       20        20            20  ...          20
# 588             10       10        10            10  ...          10
# 589             10       10        10            10  ...          10
# 590             20       20        20            20  ...          20
#
# 34   Dry_weight  Wet_weight/vol  Dry_weight/vol  Total_wet/vol  Total_dry/vol  \
# 0            18              18              18             18             18
# 1            10              10              10             10             10
# 2             8               8               8              8              8
# 3            20              20              20             20             20
# 4            10              10              10             10             10
# ..          ...             ...             ...            ...            ...
# 586          10              10              10             10             10
# 587          20              20              20             20             20
# 588          10              10              10             10             10
# 589          10              10              10             10             10
# 590          20              20              20             20             20
#
# 34   Wet/vol_norm  Dry/vol_norm  Total_wet/vol_norm  Total_dry/vol_norm
# 0              18            18                  18                  18
# 1              10            10                  10                  10
# 2               8             8                   8                   8
# 3              20            20                  20                  20
# 4              10            10                  10                  10
# ..            ...           ...                 ...                 ...
# 586            10            10                  10                  10
# 587            20            20                  20                  20
# 588            10            10                  10                  10
# 589            10            10                  10                  10
# 590            20            20                  20                  20
#
# [591 rows x 23 columns]

# %%
dt_gb['YearMonth'] = dt_gb['Date'].dt.to_period('M')
ym_gb = dt_gb.groupby('YearMonth').count()
ym_gb
# Out:
# 34         Date  Cruise  Tow  Latitiude_Deg  Latitude_Min  Longitude_Deg  \
# YearMonth
# 1994-04       3       3    3              3             3              3
# 1994-05       1       1    1              1             1              1
# 1994-06       2       2    2              2             2              2
# 1994-07       2       2    2              2             2              2
# 1994-08       2       2    2              2             2              2
# ...         ...     ...  ...            ...           ...            ...
# 2022-08       1       1    1              1             1              1
# 2022-09       2       2    2              2             2              2
# 2022-10       1       1    1              1             1              1
# 2022-11       2       2    2              2             2              2
# 2022-12       1       1    1              1             1              1
#
# 34         Longitude_Min  Time_in  Time_out  Duration_min  ...  Wet_weight  \
# YearMonth                                                  ...
# 1994-04                3        3         3             3  ...           3
# 1994-05                1        1         1             1  ...           1
# 1994-06                2        2         2             2  ...           2
# 1994-07                2        2         2             2  ...           2
# 1994-08                2        2         2             2  ...           2
# ...                  ...      ...       ...           ...  ...         ...
# 2022-08                1        1         1             1  ...           1
# 2022-09                2        2         2             2  ...           2
# 2022-10                1        1         1             1  ...           1
# 2022-11                2        2         2             2  ...           2
# 2022-12                1        1         1             1  ...           1
#
# 34         Dry_weight  Wet_weight/vol  Dry_weight/vol  Total_wet/vol  \
# YearMonth
# 1994-04             3               3               3              3
# 1994-05             1               1               1              1
# 1994-06             2               2               2              2
# 1994-07             2               2               2              2
# 1994-08             2               2               2              2
# ...               ...             ...             ...            ...
# 2022-08             1               1               1              1
# 2022-09             2               2               2              2
# 2022-10             1               1               1              1
# 2022-11             2               2               2              2
# 2022-12             1               1               1              1
#
# 34         Total_dry/vol  Wet/vol_norm  Dry/vol_norm  Total_wet/vol_norm  \
# YearMonth
# 1994-04                3             3             3                   3
# 1994-05                1             1             1                   1
# 1994-06                2             2             2                   2
# 1994-07                2             2             2                   2
# 1994-08                2             2             2                   2
# ...                  ...           ...           ...                 ...
# 2022-08                1             1             1                   1
# 2022-09                2             2             2                   2
# 2022-10                1             1             1                   1
# 2022-11                2             2             2                   2
# 2022-12                1             1             1                   1
#
# 34         Total_dry/vol_norm
# YearMonth
# 1994-04                     3
# 1994-05                     1
# 1994-06                     2
# 1994-07                     2
# 1994-08                     2
# ...                       ...
# 2022-08                     1
# 2022-09                     2
# 2022-10                     1
# 2022-11                     2
# 2022-12                     1
#
# [321 rows x 23 columns]

# %%
full_range = pd.period_range(start="1994-04", end="2022-12", freq="M")
missing_months = full_range.difference(ym_gb.index)
print(missing_months)
# Out:
# PeriodIndex(['2000-01', '2003-06', '2006-03', '2008-11', '2008-12', '2009-01',
#              '2010-01', '2011-01', '2011-02', '2011-10', '2014-01', '2014-02',
#              '2014-05', '2015-01', '2015-10', '2016-01', '2016-02', '2017-03',
#              '2020-03', '2020-04', '2020-05', '2020-06', '2022-02', '2022-04'],
#             dtype='period[M]')

# %%
ym_gb.loc['2000-02']
# Out:
# 34
# Date                  4
# Cruise                4
# Tow                   4
# Latitiude_Deg         4
# Latitude_Min          4
# Longitude_Deg         4
# Longitude_Min         4
# Time_in               4
# Time_out              4
# Duration_min          4
# Max_depth             4
# Water_Vol             4
# Sieve_Size            4
# Wet_weight            4
# Dry_weight            4
# Wet_weight/vol        4
# Dry_weight/vol        4
# Total_wet/vol         4
# Total_dry/vol         4
# Wet/vol_norm          4
# Dry/vol_norm          4
# Total_wet/vol_norm    4
# Total_dry/vol_norm    4
# Name: 2000-02, dtype: int64

# %%
df['YearMonth'] = df['Date'].dt.to_period('M')
df[df['YearMonth'] == '2000-02']
df['Total_dry/vol_norm'] = df['Total_dry/vol_norm'].astype(float)
df = df[['YearMonth','Total_dry/vol_norm']].groupby('YearMonth').mean()
df = df[df['Total_dry/vol_norm'] > 0 ]
df
# Out:
# 34         Total_dry/vol_norm
# YearMonth
# 1994-04            167.247222
# 1994-05            151.395000
# 1994-06            243.672500
# 1994-07            219.662500
# 1994-08            320.070000
# ...                       ...
# 2022-07            546.185000
# 2022-08            530.362500
# 2022-09            368.873333
# 2022-11            239.367500
# 2022-12            367.515000
#
# [316 rows x 1 columns]

# %%
df.plot()
# Out:
# <Axes: xlabel='YearMonth'>

# %%
full_range = pd.period_range(start="1994-04", end="2022-12", freq="M")
missing_months = full_range.difference(df.index)
print(missing_months)
# Out:
# PeriodIndex(['2000-01', '2000-03', '2000-05', '2003-06', '2006-03', '2008-11',
#              '2008-12', '2009-01', '2010-01', '2010-08', '2011-01', '2011-02',
#              '2011-10', '2014-01', '2014-02', '2014-05', '2014-06', '2015-01',
#              '2015-10', '2016-01', '2016-02', '2017-03', '2020-03', '2020-04',
#              '2020-05', '2020-06', '2022-02', '2022-04', '2022-10'],
#             dtype='period[M]')

# %%
#Fill in missing months
full_range = pd.period_range(start="1994-04", end="2022-12", freq="M")
df = df.reindex(full_range)
df.reset_index(inplace=True)
df.rename(columns={'index': 'YearMonth'}, inplace=True)
df
# Out:
# 34  YearMonth  Total_dry/vol_norm
# 0     1994-04          167.247222
# 1     1994-05          151.395000
# 2     1994-06          243.672500
# 3     1994-07          219.662500
# 4     1994-08          320.070000
# ..        ...                 ...
# 340   2022-08          530.362500
# 341   2022-09          368.873333
# 342   2022-10                 NaN
# 343   2022-11          239.367500
# 344   2022-12          367.515000
#
# [345 rows x 2 columns]

# %%
#should have no missing months 
full_range = pd.period_range(start="1994-04", end="2022-12", freq="M")
missing_months = full_range.difference(df['YearMonth'])
print(missing_months)
# Out:
# PeriodIndex([], dtype='period[M]')

# %%
df.plot()
# Out:
# <Axes: >

# %%
df.to_csv('../Data/BATS_cleaned.csv')
